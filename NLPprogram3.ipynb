# %%
# !pip install sentence-transformers datasets
# !pip install scikit-learn
# !pip install --upgrade pip
# !pip install SpeechRecognition
# !pip install pyautogui
# !pip install clipboard
# !pip install keyboard
# !pip install pyaudio

# %%
# !pip install sentence-transformers datasets
# !pip install scikit-learn
# !pip install --upgrade pip
# !pip install SpeechRecognition
# !pip install pyautogui
# !pip install clipboard
# !pip install keyboard
# !pip install pyaudio

import time
import tkinter
import tkinter.filedialog

from torch.utils.data import DataLoader
from datasets import load_dataset
from sentence_transformers import SentenceTransformer,  LoggingHandler, losses, models, util
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from sentence_transformers.readers import InputExample
from sklearn.cluster import KMeans
from speech_recognition import *
from pyautogui import *


import math
import logging

import torch
from torch.utils.data import DataLoader
from datasets import load_dataset
from sentence_transformers import SentenceTransformer,  LoggingHandler, losses, models, util
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from sentence_transformers.readers import InputExample
from sklearn.cluster import KMeans

from speech_recognition import *
from pyautogui import *
import clipboard
import keyboard
import pyaudio
import time # 필요한 모듈 불러오기
from datetime import datetime


    
window=tkinter.Tk()
window.title("Emergency Program")
window.geometry("1900x1000+0+0")
window.resizable(True, True)
    
    
    
class main():  
    def mainpage(self):
        #전화벨 함수
        def change_a():
            global photo2
            photo2 = tkinter.PhotoImage(file="./1.PNG")
            callbutton.config(image=photo2 ,command = change_b)    
            # 사진 초기화
            global photo4
            photo4 = tkinter.PhotoImage(file="./gps/defalut.PNG")
            gpsphoto_label.config(image=photo4)
            # 입력 초기화
            hospital_text.delete("1.0","end")
            tsd_text.delete("1.0","end")
            result_text.delete("1.0","end")
            similarity_text.delete("1.0","end")
            Current_call_text.delete("1.0","end")
            Current_loc_text.delete("1.0","end")
            Current_time_text.delete("1.0","end")
            call_number_text.delete("1.0","end")

        def change_b():
            Current_time_text.delete("1.0","end")
            call_number_text.delete("1.0","end")
            Current_loc_text.delete("1.0","end")
            global photo2
            photo2 = tkinter.PhotoImage(file="./2.PNG")
            callbutton.config(image=photo2 ,command = change_a)    
            now = datetime.now()   
            time=str(now.year)+"년 "+str(now.hour)+"시 "+str(now.minute)+"분 "+str(now.second)+"초"
            Current_time_text.insert(tkinter.CURRENT, time)
            call_number_text.insert(tkinter.CURRENT, "010-1234-5678")
            Current_loc_text.insert(tkinter.CURRENT, "경상북도 포항시 남구 청암로 77")


        def change_c():
            global photo2
            photo2 = tkinter.PhotoImage(file="./3.PNG")
            callbutton.config(image=photo2 ,command =change_b)


        def read_voice(): # 음성 인식을 하는 함수
            r = Recognizer()
            mic = Microphone() # 마이크 객체
            with mic as source:
                audio = r.listen(source) # 음성 읽어오기
            voice_data = r.recognize_google(audio, language='ko')
            Current_call_text.insert(tkinter.CURRENT, voice_data)


        def State(voice):
            query = voice
            query_embedding = model.encode(query)
            top_k = min(len(docs), len(docs))
            # 입력 문장 - 문장 후보군 간 코사인 유사도 계산 후,
            cos_scores = util.pytorch_cos_sim(query_embedding, document_embeddings)[0]

            # 코사인 유사도 순으로 `top_k` 개 문장 추출
            top_results = torch.topk(cos_scores, k=top_k)

            print(f"입력 문장: {query}")
            print(f"\n<입력 문장과 비교한 {top_k} 개의 문장>\n")
            
            for (root, directories, files) in os.walk(dir_path):
                for file in files:
                    file_path = os.path.join(root, file)
            #        count[(file_path.split('\\')[-1]).split('.txt')[0]]=0
                    dic[file_path] = 0
            
            for i, (score, idx) in enumerate(zip(top_results[0], top_results[1])):
                if score > 0.5:
                    similarity_text.insert(tkinter.CURRENT, f"{i+1}: {docs[idx]} \n{'(유사도: {:.4f})'.format(score)}\n")
                    for i in dic:
                        file= open(i, 'rt' , encoding='UTF8')
                        passwords = file.readlines()
                        for password in passwords:
                            password = password.replace('\n', '')     
                            if password == docs[idx]:
                                print(password)
                                print(docs[idx])
                                print(dic)
                                dic[i]+=1
            #similarity_text.insert(tkinter.CURRENT, dic)    
    
    
            result = [] 
            for key, value in dic.items():
                if value >7:
                    result.append((key.split('\\')[-1]).split('.txt')[0])
            result = list(set(result))            
            
            
            resultT = "분석결과 : "
            for i in range(len(result)):
                resultT += result[i] + " "    
            resultT += "\n\n" 
            result_text.insert(tkinter.CURRENT,  resultT)
            
            
            info =""
            info1 =""
            info2 =""
            for i in range(len(result)):
                if result[i] == "압좌증후군":
                    global photo4
                    photo4 = tkinter.PhotoImage(file="./gps/압좌증후군.PNG")
                    gpsphoto_label.config(image=photo4)
                    
                    
                    file= open('./data2/압좌증후군.txt', 'rt' , encoding='UTF8')
                    passwords = file.readlines()
                    for password in passwords:
                        info += password
                    info += "\n\n"    
                    
                    file1= open('./data2/압좌증후군 지정병원.txt', 'rt' , encoding='UTF8')
                    passwords = file1.readlines()
                    for password in passwords:
                        info1 += password
 
                    file2= open('./data2/압좌증후군 병원사항.txt', 'rt' , encoding='UTF8')
                    passwords = file2.readlines()
                    for password in passwords:
                        info2 += password
            
    
#             if result[0] == "협심증":
#                 photo4 = tkinter.PhotoImage(file="./gps/협심증.PNG")
#                 gpsphoto_label.config(image=photo4)

#                 file3= open('./data2/협심증 지정병원.txt', 'rt' , encoding='UTF8')
#                 passwords = file3.readlines()
#                 for password in passwords:
#                     info1 += password
 
#                 file4= open('./data2/협심증 병원사항.txt', 'rt' , encoding='UTF8')
#                 passwords = file4.readlines()
#                 for password in passwords:
#                     info2 += password
                            
                
#             elif result[0] == "심근경색":
#                 photo4 = tkinter.PhotoImage(file="./gps/심근경색.PNG")
#                 gpsphoto_label.config(image=photo4)

#                 file5= open('./data2/심근경색 지정병원.txt', 'rt' , encoding='UTF8')
#                 passwords = file5.readlines()
#                 for password in passwords:
#                     info1 += password
 
#                 file6= open('./data2/심근경색 병원사항.txt', 'rt' , encoding='UTF8')
#                 passwords = file6.readlines()
#                 for password in passwords:
#                     info2 += password
                                            
                
    
            result_text.insert(tkinter.CURRENT,  info)
            tsd_text.insert(tkinter.CURRENT,  info1)
            hospital_text.insert(tkinter.CURRENT,  info2)
    
        # nlp
        datasets = load_dataset("klue", "sts")
        testsets = load_dataset("kor_nlu", "sts")
        train_samples = []
        dev_samples = []
        test_samples = []

        # KLUE STS 내 훈련, 검증 데이터 예제 변환
        for phase in ["train", "validation"]:
            examples = datasets[phase]

            for example in examples:
                score = float(example["labels"]["label"]) / 5.0  # 0.0 ~ 1.0 스케일로 유사도 정규화

                inp_example = InputExample(
                    texts=[example["sentence1"], example["sentence2"]], 
                    label=score,
                )

                if phase == "validation":
                    dev_samples.append(inp_example)
                else:
                    train_samples.append(inp_example)

        # KorSTS 내 테스트 데이터 예제 변환
        for example in testsets["test"]:
            score = float(example["score"]) / 5.0

            if example["sentence1"] and example["sentence2"]:
                inp_example = InputExample(
                    texts=[example["sentence1"], example["sentence2"]],
                    label=score,
                )

            test_samples.append(inp_example)


        model_save_path = "training_klue_sts_klue-roberta-base-2022-12-18_19-36-15"
        model = SentenceTransformer(model_save_path)
        test_evaluator = EmbeddingSimilarityEvaluator.from_input_examples(test_samples, name='sts-test')
        test_evaluator(model, output_path=model_save_path)


        docs = []
        dic = {}

        dir_path = "./data/"

        for (root, directories, files) in os.walk(dir_path):
            for file in files:
                file_path = os.path.join(root, file)
                dic[file_path] = 0

        for i in dic:
            file= open(i, 'rt' , encoding='UTF8')
            passwords = file.readlines()
            for password in passwords:
            #print(password)
                password = password.replace('\n', '')
                docs.append(password)        
        
        document_embeddings = model.encode(docs)
            

        #메뉴바 설정
        menubar=tkinter.Menu(window)

        menu_1=tkinter.Menu(menubar, tearoff=0)
        menubar.add_cascade(label="Dashboard", menu=menu_1)
        
        menu_2=tkinter.Menu(menubar, tearoff=0)
        menubar.add_cascade(label="Local", menu=menu_2)
        
        menu_3=tkinter.Menu(menubar, tearoff=0)
        menu_3.add_command(label="기록" )
        menubar.add_cascade(label="Log", menu=menu_3)
        
        menu_4=tkinter.Menu(menubar, tearoff=0)
        menubar.add_cascade(label="Network", menu=menu_4)        
        
        menu_5=tkinter.Menu(menubar, tearoff=0)
        menu_5.add_command(label="NLP 시작" )
        menubar.add_cascade(label="Option", menu=menu_5 ) 

        window.config(menu=menubar)

        # 전화번호
        call_number_label = tkinter.Label(window, text="전화번호")
        call_number_label.configure(font=(40))  
        call_number_label.place(x=40, y= 30)

        call_number_text = tkinter.Text(window,width=32,height=3 )
        call_number_text.configure(font=(40))
        call_number_text.place(x=40, y =60)

        # 현재시간
        Current_time_label=tkinter.Label(window, text="현재 시간")
        Current_time_label.configure(font=(40))  
        Current_time_label.place(x=40, y=140)

        Current_time_text=tkinter.Text(window,width=32,height=3 )
        Current_time_text.configure(font=(40))
        Current_time_text.place(x=40, y=170)

        # 현재 위치
        Current_loc_label=tkinter.Label(window, text="현재 위치")
        Current_loc_label.configure(font=(40))  
        Current_loc_label.place(x=40, y=250)

        Current_loc_text=tkinter.Text(window,width=32,height=3 )
        Current_loc_text.configure(font=(40))
        Current_loc_text.place(x=40, y=280)


        # 대화내용
        Current_call_label=tkinter.Label(window, text="대화 내용")
        Current_call_label.configure(font=(40))  
        Current_call_label.place(x=450, y=30)

        Current_call_text=tkinter.Text(window,width=100,height=8)
        Current_call_text.place(x=450, y=60)




        # 유사도 분석
        similarity_label=tkinter.Label(window, text="유사도 분석")
        similarity_label.configure(font=(40))  
        similarity_label.place(x=450, y=250)

        similarity_text=tkinter.Text(window,width=100,height=12 )
        similarity_text.place(x=450, y=280)



        # 분석 결과
        result_label=tkinter.Label(window, text="분석 결과")
        result_label.configure(font=(40))  
        result_label.place(x=450, y=550)

        result_text=tkinter.Text(window,width=100,height=20 )
        result_text.place(x=450, y=580)


        # 녹음 버튼  callbutton.place(x=40, y=400)
        record=tkinter.Button(window,width=12,height=2, text="일반 녹음" , command=read_voice)
        record.configure(font=(40))
        record.place(x=40, y=680) 


        # 분석 버튼
        Analysis=tkinter.Button(window,width=12,height=2, text="분석" ,command=lambda: State(Current_call_text.get("1.0","end")) )
        Analysis.configure(font=(40))
        Analysis.place(x=40, y=740)



        #전화벨 사진
        photo = tkinter.PhotoImage(file="./1.PNG")
        callbutton = tkinter.Button(window,width=230,height=230 ,image=photo ,command = change_b)
        callbutton.place(x=40, y=400)


        # gps 사진
        gpsphoto = tkinter.PhotoImage(file="./gps/defalut.png")
        gpsphoto_label = tkinter.Label(window,width=450,height=430 ,image=gpsphoto )
        gpsphoto_label.place(x=1400, y=60)


        # 거리 , 당진 , 의료기구 보유

        tsd_label=tkinter.Label(window, text="지정 병원")
        tsd_label.configure(font=(40))  
        tsd_label.place(x=1400, y=550)

        tsd_text=tkinter.Text(window,width=40,height=3 )
        tsd_text.place(x=1400, y=580)


        hospital_label=tkinter.Label(window, text="병원 사항")

        hospital_label.configure(font=(40))  
        hospital_label.place(x=1400, y=650)

        hospital_text=tkinter.Text(window,width=40,height=10 )
        hospital_text.place(x=1400, y=680)

        window.mainloop()


if __name__=='__main__':        
    main().mainpage()
# Out:
# Found cached dataset klue (C:/Users/maili/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Found cached dataset kor_nlu (C:/Users/maili/.cache/huggingface/datasets/kor_nlu/sts/1.0.0/4facbba77df60b0658056ced2052633e681a50187b9428bd5752ebd59d332ba8)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 입력 문장: 가슴을 쮜어 짜는 통증잉 있습니다
#
#
# <입력 문장과 비교한 46 개의 문장>
#
# 날이 추워지고서 부터 가슴 부위의 통증으로 쥐어짜는 느낌과 함께 쥐가 나는 느낌 뻐근하고 명치가 쓰리는 느낌이 들어요. 그런데 시간이 조금 지나면 괜찮아져서 정말로 아픈건지 단순히 스트레스를 많이 받아서 그런지 모르겠어요. 이런 증상의 병이 있나요?
# 날이 추워지고서 부터 가슴 부위의 통증으로 쥐어짜는 느낌과 함께 쥐가 나는 느낌 뻐근하고 명치가 쓰리는 느낌이 들어요. 그런데 시간이 조금 지나면 괜찮아져서 정말로 아픈건지 단순히 스트레스를 많이 받아서 그런지 모르겠어요. 이런 증상의 병이 있나요?
# {'./data/내과\\심근경색\\심근경색.txt': 0, './data/내과\\협심증\\협심증.txt': 0, './data/특수사항\\특수사항.txt': 0}
# 작년 12월 말부터 현재까지도 가슴에 아주 작은 통증이 있었는데. 갑자기 숨을 쉬기 힘들고 가슴을 쥐어짜는 통증을 느꼈습니다
# 작년 12월 말부터 현재까지도 가슴에 아주 작은 통증이 있었는데. 갑자기 숨을 쉬기 힘들고 가슴을 쥐어짜는 통증을 느꼈습니다
# {'./data/내과\\심근경색\\심근경색.txt': 0, './data/내과\\협심증\\협심증.txt': 1, './data/특수사항\\특수사항.txt': 0}
# 얼마전 흉통없이 가슴이 짓눌리는 듯 답답한 느낌과 함께 팔이 욱신거렸습니다.
# 얼마전 흉통없이 가슴이 짓눌리는 듯 답답한 느낌과 함께 팔이 욱신거렸습니다.
# {'./data/내과\\심근경색\\심근경색.txt': 1, './data/내과\\협심증\\협심증.txt': 1, './data/특수사항\\특수사항.txt': 0}
# 오늘 아침부터 밤까지 가슴 중앙에 통증이 하루종일 지속됩니다. 일어설 때 앉을 때 걸을 때 문을 열 때 등등 가슴 중앙부가 쥐어짜는 것처럼 순간순간 아픕니다. 인터넷에 찾아보니 심근경색 전조증상과 유사한거 같아 갑자기 걱정됩니다.
# 오늘 아침부터 밤까지 가슴 중앙에 통증이 하루종일 지속됩니다. 일어설 때 앉을 때 걸을 때 문을 열 때 등등 가슴 중앙부가 쥐어짜는 것처럼 순간순간 아픕니다. 인터넷에 찾아보니 심근경색 전조증상과 유사한거 같아 갑자기 걱정됩니다.
# {'./data/내과\\심근경색\\심근경색.txt': 2, './data/내과\\협심증\\협심증.txt': 1, './data/특수사항\\특수사항.txt': 0}
# 눌렀을때 아프지 않는데 가슴이 답답하고 이 불쾌감 자주 느껴집니다 그때마다 숨을 쉬기 어렵습니다
# 눌렀을때 아프지 않는데 가슴이 답답하고 이 불쾌감 자주 느껴집니다 그때마다 숨을 쉬기 어렵습니다
# {'./data/내과\\심근경색\\심근경색.txt': 3, './data/내과\\협심증\\협심증.txt': 1, './data/특수사항\\특수사항.txt': 0}
# 심장을 짓누르는 느낌이 나고 가슴을 콕콕 찌르는 것 같이 아프고, 밤에 자려고 누우면 누운 상태에서도 짓누르는 느낌이 나요. 가끔은 자는 도중에 새벽에 통증으로 잠에서 깨기도 해요.
# 심장을 짓누르는 느낌이 나고 가슴을 콕콕 찌르는 것 같이 아프고, 밤에 자려고 누우면 누운 상태에서도 짓누르는 느낌이 나요. 가끔은 자는 도중에 새벽에 통증으로 잠에서 깨기도 해요.
# {'./data/내과\\심근경색\\심근경색.txt': 4, './data/내과\\협심증\\협심증.txt': 1, './data/특수사항\\특수사항.txt': 0}
# 작년 12월 말부터 현재까지도 가슴에 아주 작은 통증이 있습니다. 숨을 쉬기 힘들다거나, 쥐어짠다거나 그런 통증은 단 한번도 없었습니다. 그냥... 작은 바늘로 콕콕 찌르는 느낌? 정말 약하게 쥐어짜는 느낌 아 근데 작년 9월부터 헬스 다니면서 꾸준히 운동을 하기도 했어요. 그때는 가슴 통증이 전혀 느껴지지 않았구요.
# 작년 12월 말부터 현재까지도 가슴에 아주 작은 통증이 있습니다. 숨을 쉬기 힘들다거나, 쥐어짠다거나 그런 통증은 단 한번도 없었습니다. 그냥... 작은 바늘로 콕콕 찌르는 느낌? 정말 약하게 쥐어짜는 느낌 아 근데 작년 9월부터 헬스 다니면서 꾸준히 운동을 하기도 했어요. 그때는 가슴 통증이 전혀 느껴지지 않았구요.
# {'./data/내과\\심근경색\\심근경색.txt': 4, './data/내과\\협심증\\협심증.txt': 2, './data/특수사항\\특수사항.txt': 0}
# 갑자기 가슴에 압박 쥐어짜는 듯한 통증이 오더니  식은 땀이 나면서 숨쉬기가 힘들었습니다
# 갑자기 가슴에 압박 쥐어짜는 듯한 통증이 오더니  식은 땀이 나면서 숨쉬기가 힘들었습니다
# {'./data/내과\\심근경색\\심근경색.txt': 5, './data/내과\\협심증\\협심증.txt': 2, './data/특수사항\\특수사항.txt': 0}
# 왼쪽 가슴이 시린 느낌, 싸한 느낌이라고 할지 서늘하다고 할지 모를 느낌입니다 눌러서 아픈곳은 없으나, 가슴이 답답하고 이 불쾌감 때문에 안절부절 못하게 됩니다 가끔가다 명치부터 올라오는 싸한 느낌 혹은 놀이기구 등을 탈때의 얼얼한 느낌이 있습니다.
# 왼쪽 가슴이 시린 느낌, 싸한 느낌이라고 할지 서늘하다고 할지 모를 느낌입니다 눌러서 아픈곳은 없으나, 가슴이 답답하고 이 불쾌감 때문에 안절부절 못하게 됩니다 가끔가다 명치부터 올라오는 싸한 느낌 혹은 놀이기구 등을 탈때의 얼얼한 느낌이 있습니다.
# {'./data/내과\\심근경색\\심근경색.txt': 6, './data/내과\\협심증\\협심증.txt': 2, './data/특수사항\\특수사항.txt': 0}
# 가슴이 조이는 느낌 뻐근하고 결리는 느낌 명치가 쓰리는 느낌 이런 증상이 저한테 있는데요. 협심증전조증상으로 보면 되나요?
# 가슴이 조이는 느낌 뻐근하고 결리는 느낌 명치가 쓰리는 느낌 이런 증상이 저한테 있는데요. 협심증전조증상으로 보면 되나요?
# {'./data/내과\\심근경색\\심근경색.txt': 7, './data/내과\\협심증\\협심증.txt': 2, './data/특수사항\\특수사항.txt': 0}
# 가슴쪽이 30분가량 쮜어짜는 통증이 있고  팔, 어깨로 이어지는 통증을 느꼈습니다  심장쪽 조금 저릿하고 심장쪽부터 시작해서 방사통이 퍼져나갑니다
# 가슴쪽이 30분가량 쮜어짜는 통증이 있고  팔, 어깨로 이어지는 통증을 느꼈습니다  심장쪽 조금 저릿하고 심장쪽부터 시작해서 방사통이 퍼져나갑니다
# {'./data/내과\\심근경색\\심근경색.txt': 7, './data/내과\\협심증\\협심증.txt': 3, './data/특수사항\\특수사항.txt': 0}
# 며칠전부터 왼쪽 왼쪽 가슴이 쥐어짠다기보다 누르는 듯한 통증이 있습니다 그리고 통증이 왼쪽 어깨로 올라온 거 같기도 하구요
# 며칠전부터 왼쪽 왼쪽 가슴이 쥐어짠다기보다 누르는 듯한 통증이 있습니다 그리고 통증이 왼쪽 어깨로 올라온 거 같기도 하구요
# {'./data/내과\\심근경색\\심근경색.txt': 8, './data/내과\\협심증\\협심증.txt': 3, './data/특수사항\\특수사항.txt': 0}
# 할아버지가 갑자기 가슴쪽에 심한 통증이 느껴지신다고 움직일 수 가 없어해요 몇일전부터 계속 속이 메스껍다 하셨구요 식은 땀도 자주나시는데 심근경색 전조증상 일까요
# 할아버지가 갑자기 가슴쪽에 심한 통증이 느껴지신다고 움직일 수 가 없어해요 몇일전부터 계속 속이 메스껍다 하셨구요 식은 땀도 자주나시는데 심근경색 전조증상 일까요
# {'./data/내과\\심근경색\\심근경색.txt': 9, './data/내과\\협심증\\협심증.txt': 3, './data/특수사항\\특수사항.txt': 0}
# 최근 심장이 있는 가슴 특히 왼쪽이 조이듯한 통증이 있고, 고춧가루 뿌려놓은 듯이 가슴이 쓰려요. 흡연 중이긴 한데 폐가 문제인지 심장이 문제인지 잘 모르겠어요.
# 최근 심장이 있는 가슴 특히 왼쪽이 조이듯한 통증이 있고, 고춧가루 뿌려놓은 듯이 가슴이 쓰려요. 흡연 중이긴 한데 폐가 문제인지 심장이 문제인지 잘 모르겠어요.
# {'./data/내과\\심근경색\\심근경색.txt': 10, './data/내과\\협심증\\협심증.txt': 3, './data/특수사항\\특수사항.txt': 0}
# 최근 지속적으로 10분이상 가슴통증이 느껴집니다. 가족력으로 고혈압이 있어서 현재 약을 복용하고 있습니다. 고혈압이 가슴통증과 관련이 있을까요?
# 최근 지속적으로 10분이상 가슴통증이 느껴집니다. 가족력으로 고혈압이 있어서 현재 약을 복용하고 있습니다. 고혈압이 가슴통증과 관련이 있을까요?
# {'./data/내과\\심근경색\\심근경색.txt': 10, './data/내과\\협심증\\협심증.txt': 4, './data/특수사항\\특수사항.txt': 0}
# 갑자기 가슴 통증이 20분이상 지속적으로 되고 운동 직후에 보통 증상이 있는 편 입니다 처음에는 과격하게 운동을 해서 그렇다고 생각했는데 가슴 통증이 지속적으로 발생합니다 그리고 당뇨가 있어서 약을 복용 중이라 걱정이 많습니다
# 갑자기 가슴 통증이 20분이상 지속적으로 되고 운동 직후에 보통 증상이 있는 편 입니다 처음에는 과격하게 운동을 해서 그렇다고 생각했는데 가슴 통증이 지속적으로 발생합니다 그리고 당뇨가 있어서 약을 복용 중이라 걱정이 많습니다
# {'./data/내과\\심근경색\\심근경색.txt': 11, './data/내과\\협심증\\협심증.txt': 4, './data/특수사항\\특수사항.txt': 0}
# 양쪽 가슴 가운데부분(명치와 목 중간사이)이 5분간격으로 통증이 있어요. 오늘 오전부터 갑자기 아프기 시작하더니 지금까지 계속 아프네요.
# 양쪽 가슴 가운데부분(명치와 목 중간사이)이 5분간격으로 통증이 있어요. 오늘 오전부터 갑자기 아프기 시작하더니 지금까지 계속 아프네요.
# {'./data/내과\\심근경색\\심근경색.txt': 12, './data/내과\\협심증\\협심증.txt': 4, './data/특수사항\\특수사항.txt': 0}
# 3시간전부터 심장이 꽉 조이듯 아프면서 답답하고 체한느낌들면서 가슴이 답답한데 목에도 뭐 걸린 느낌드는데 혹시 빨리 병원에 가야할까요? 아니면 조금 지나면 괜찮아질까요?
# 3시간전부터 심장이 꽉 조이듯 아프면서 답답하고 체한느낌들면서 가슴이 답답한데 목에도 뭐 걸린 느낌드는데 혹시 빨리 병원에 가야할까요? 아니면 조금 지나면 괜찮아질까요?
# {'./data/내과\\심근경색\\심근경색.txt': 12, './data/내과\\협심증\\협심증.txt': 5, './data/특수사항\\특수사항.txt': 0}
# 운동할 때가 아닌, 평소에 가만히 있을때에 심장쪽이 뻐근하고 심장을 바늘로 찌르는 느낌이 들었습니다. 한달에 2번 정도?의 빈도로 통증이 옵니다. 통증이 심해서 숨을 크게 내쉬었다가 들이마셨다가를 반복하면 서서히 낫습니다. 통증 시간은 15분 내외인것 같습니다.
# 운동할 때가 아닌, 평소에 가만히 있을때에 심장쪽이 뻐근하고 심장을 바늘로 찌르는 느낌이 들었습니다. 한달에 2번 정도?의 빈도로 통증이 옵니다. 통증이 심해서 숨을 크게 내쉬었다가 들이마셨다가를 반복하면 서서히 낫습니다. 통증 시간은 15분 내외인것 같습니다.
# {'./data/내과\\심근경색\\심근경색.txt': 13, './data/내과\\협심증\\협심증.txt': 5, './data/특수사항\\특수사항.txt': 0}
# 바늘로 가슴을 찌르는 것 같고, 숨도 못 쉬게 통증이 오고 그런데 짧게 지나가서 최근에 피곤해서 그런가 생각도 들어요. 그런데 제가 고혈압도 있어서 걱정이 됩니다.
# 바늘로 가슴을 찌르는 것 같고, 숨도 못 쉬게 통증이 오고 그런데 짧게 지나가서 최근에 피곤해서 그런가 생각도 들어요. 그런데 제가 고혈압도 있어서 걱정이 됩니다.
# {'./data/내과\\심근경색\\심근경색.txt': 14, './data/내과\\협심증\\협심증.txt': 5, './data/특수사항\\특수사항.txt': 0}
# 요즘 들어 잠자다가 다리에 힘을 주면 다리에 쥐가 잘 나서 잠에서 깨고요. 출근시간에 가슴 중앙 부분에 통증이 약3분정도 지속 되다가 없어지고요. 이번 달에만 2번 발생하였고요. 최근 혈액 검사에서는 모두 정상이었고 10년도 부터 고혈압 진단을 받아 약을 복욕 중 입니다. 무슨 병일까요?
# 요즘 들어 잠자다가 다리에 힘을 주면 다리에 쥐가 잘 나서 잠에서 깨고요. 출근시간에 가슴 중앙 부분에 통증이 약3분정도 지속 되다가 없어지고요. 이번 달에만 2번 발생하였고요. 최근 혈액 검사에서는 모두 정상이었고 10년도 부터 고혈압 진단을 받아 약을 복욕 중 입니다. 무슨 병일까요?
# {'./data/내과\\심근경색\\심근경색.txt': 14, './data/내과\\협심증\\협심증.txt': 6, './data/특수사항\\특수사항.txt': 0}
# 헬스장에서 런닝머신을 뛰다가 갑자기 숨쉬기가 힘들고 가슴을 짓누르며 찌르는 듯한 통증이 오느데 제가 과호흡까지 했는지 손발이 져려오며 마비되는 증상이 있어 바로 휴식을 취했는데 조금 지나니까 괜찮아졌는데 걱정이 되서 집으로 와서 바로 쉬었습니다. 운동하다가 이런적은 처음이라 걱정이 많이되는데, 고강도로 뛰어서 그런가요? 아니면 병원에 간다면 어느 과 진단을 받아볼까요?
# 헬스장에서 런닝머신을 뛰다가 갑자기 숨쉬기가 힘들고 가슴을 짓누르며 찌르는 듯한 통증이 오느데 제가 과호흡까지 했는지 손발이 져려오며 마비되는 증상이 있어 바로 휴식을 취했는데 조금 지나니까 괜찮아졌는데 걱정이 되서 집으로 와서 바로 쉬었습니다. 운동하다가 이런적은 처음이라 걱정이 많이되는데, 고강도로 뛰어서 그런가요? 아니면 병원에 간다면 어느 과 진단을 받아볼까요?
# {'./data/내과\\심근경색\\심근경색.txt': 14, './data/내과\\협심증\\협심증.txt': 7, './data/특수사항\\특수사항.txt': 0}
# 운동이나 계단 올라가는 등 활동을 할 때, 짧게 가슴 통증이 있어요. 저는 단순히 강도가 높게 운동을 해서 그렇다고 생각했는데요. 주변에 같이 운동하는 친구들에게 물어보니 그런 증상이 없다고 하네요. 검사를 빨리 받아봐야할까요?
# 운동이나 계단 올라가는 등 활동을 할 때, 짧게 가슴 통증이 있어요. 저는 단순히 강도가 높게 운동을 해서 그렇다고 생각했는데요. 주변에 같이 운동하는 친구들에게 물어보니 그런 증상이 없다고 하네요. 검사를 빨리 받아봐야할까요?
# {'./data/내과\\심근경색\\심근경색.txt': 14, './data/내과\\협심증\\협심증.txt': 8, './data/특수사항\\특수사항.txt': 0}
# 현재 고혈압 초기증상이 있습니다. 흉통은 제작년부터인가 가끔 몇달에 한번씩 왼쪽가슴 죄어오구 예를 들어 피씨방에서 잠깐 게임을 하다가도 특히 스릴있는 게임같은 거 할때요. 갑자기 한 30초동안 팍가슴이 죄어오더라구요. 꾹참고 있으니까 조금있으니까 괜찮아졌고요. 한번은 그냥 커피숖같은데 앉아있는데 왼쪽팔이 누가 꽉쥐고있는것처럼 피안통하는 느낌있자나요. 이런경험이 있었구요 최근엔 한달에 여러번도 아픈거같아요.
# 현재 고혈압 초기증상이 있습니다. 흉통은 제작년부터인가 가끔 몇달에 한번씩 왼쪽가슴 죄어오구 예를 들어 피씨방에서 잠깐 게임을 하다가도 특히 스릴있는 게임같은 거 할때요. 갑자기 한 30초동안 팍가슴이 죄어오더라구요. 꾹참고 있으니까 조금있으니까 괜찮아졌고요. 한번은 그냥 커피숖같은데 앉아있는데 왼쪽팔이 누가 꽉쥐고있는것처럼 피안통하는 느낌있자나요. 이런경험이 있었구요 최근엔 한달에 여러번도 아픈거같아요.
# {'./data/내과\\심근경색\\심근경색.txt': 14, './data/내과\\협심증\\협심증.txt': 9, './data/특수사항\\특수사항.txt': 0}
# 최근 두달 사이에 느껴지는 통증으로 2주전에 심전도를 체크했지만 이상없다는 소견이었습니다. 통증은 전부 왼쪽 가슴, 심장 위치에 가슴 통증이 지속적으로 발생합니다. 그리고 가족력으로 당뇨가 있는데 당뇨와 심장질환이 관계가 있나요?
# 최근 두달 사이에 느껴지는 통증으로 2주전에 심전도를 체크했지만 이상없다는 소견이었습니다. 통증은 전부 왼쪽 가슴, 심장 위치에 가슴 통증이 지속적으로 발생합니다. 그리고 가족력으로 당뇨가 있는데 당뇨와 심장질환이 관계가 있나요?
# {'./data/내과\\심근경색\\심근경색.txt': 14, './data/내과\\협심증\\협심증.txt': 10, './data/특수사항\\특수사항.txt': 0}

# %%
window=tkinter.Tk()
window.title("Emergency Program")
window.geometry("900x700+100+100")
window.resizable(True, True)

#메뉴바 설정
menubar=tkinter.Menu(window)

menu_1=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Dashboard", menu=menu_1)
menu_4=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Local", menu=menu_4)
menu_5=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Log", menu=menu_5)
menu_2=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Network", menu=menu_2)        
menu_3=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Option", menu=menu_3) 

window.config(menu=menubar)

# 전화번호
call_number_label = tkinter.Label(window, text="전화번호")
call_number_label.configure(font=(40))  
call_number_label.place(x=40, y= 30)

call_number_text = tkinter.Text(window,width=40,height=3 )
call_number_text.configure(font=(40))
call_number_text.place(x=40, y =60)

# 현재시간
Current_time_label=tkinter.Label(window, text="현재 시간")
Current_time_label.configure(font=(40))  
Current_time_label.place(x=40, y=120)

Current_time_text=tkinter.Text(window,width=40,height=3 )
Current_time_text.configure(font=(40))
Current_time_text.place(x=40, y=150)

# 현재 위치
Current_loc_label=tkinter.Label(window, text="현재 위치")
Current_loc_label.configure(font=(40))  
Current_loc_label.place(x=40, y=210)

Current_loc_text=tkinter.Text(window,width=40,height=3 )
Current_loc_text.configure(font=(40))
Current_loc_text.place(x=40, y=240)


# 대화내용
Current_call_label=tkinter.Label(window, text="대화 내용")
Current_call_label.configure(font=(40))  
Current_call_label.place(x=500, y=30)

Current_call_text=tkinter.Text(window,width=120,height=15)
Current_call_text.place(x=500, y=60)
 
    
def read_voice(): # 음성 인식을 하는 함수
    r = Recognizer()
    mic = Microphone() # 마이크 객체
    with mic as source:
        audio = r.listen(source) # 음성 읽어오기
    voice_data = r.recognize_google(audio, language='ko')
    Current_call_text.insert(tkinter.CURRENT, voice_data)


# 녹음 버튼
record=tkinter.Button(window,width=12,height=2, text="일반 녹음" , command=read_voice)
record.configure(font=(40))
record.place(x=955, y=280) 

Sound = tkinter.Button(window,width=12,height=2, text="NC 녹음")
Sound.configure(font=(40))
Sound.place(x=1090, y=280)

# 분석 버튼
Analysis=tkinter.Button(window,width=12,height=2, text="분석" ,command=lambda: State(Current_call_text.get("1.0","end")) )
Analysis.configure(font=(40))
Analysis.place(x=1225, y=280)

# 분석 결과
Result_label=tkinter.Label(window, text="분석 결과")
Result_label.configure(font=(40))  
Result_label.place(x=500, y=350)

Result_text=tkinter.Text(window,width=120,height=15 )
Result_text.place(x=500, y=380)



def change_a():
    global photo2
    photo2 = tkinter.PhotoImage(file="./1.PNG")
    callbutton.config(image=photo2 ,command = change_b)    
    
    

def change_b():
    Current_time_text.delete("1.0","end")
    call_number_text.delete("1.0","end")
    Current_loc_text.delete("1.0","end")
    global photo2
    photo2 = tkinter.PhotoImage(file="./2.PNG")
    callbutton.config(image=photo2 ,command = change_a)    
    now = datetime.now()   
    time=str(now.year)+"년 "+str(now.hour)+"시 "+str(now.minute)+"분 "+str(now.second)+"초"
    Current_time_text.insert(tkinter.CURRENT, time)
    call_number_text.insert(tkinter.CURRENT, "010-1234-5678")
    Current_loc_text.insert(tkinter.CURRENT, "경상북도 포항시 남구 청암로 77")



photo = tkinter.PhotoImage(file="./1.PNG")
callbutton = tkinter.Button(window,width=230,height=230 ,image=photo ,command = change_b)
callbutton.place(x=40, y=500)


window.mainloop()

# %%
def State(voice):
    query = voice
    query_embedding = model.encode(query)
    top_k = min(len(docs), len(docs))
    # 입력 문장 - 문장 후보군 간 코사인 유사도 계산 후,
    cos_scores = util.pytorch_cos_sim(query_embedding, document_embeddings)[0]

    # 코사인 유사도 순으로 `top_k` 개 문장 추출
    top_results = torch.topk(cos_scores, k=top_k)
    
    print(f"입력 문장: {query}")
    print(f"\n<입력 문장과 비교한 {top_k} 개의 문장>\n")
    
    for i, (score, idx) in enumerate(zip(top_results[0], top_results[1])):
        if score > 0.5:
            Result_text.insert(tkinter.CURRENT, f"{i+1}: {docs[idx]} \n{'(유사도: {:.4f})'.format(score)}\n")

# %%
import time
import tkinter
import tkinter.filedialog

import math
import logging


from speech_recognition import *
from pyautogui import *
import clipboard
import keyboard
import pyaudio
import time # 필요한 모듈 불러오기
from datetime import datetime

window=tkinter.Tk()
window.title("Emergency Program")
window.geometry("1900x1000+0+0")
window.resizable(True, True)

#메뉴바 설정
menubar=tkinter.Menu(window)

menu_1=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Dashboard", menu=menu_1)
menu_4=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Local", menu=menu_4)
menu_5=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Log", menu=menu_5)
menu_2=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Network", menu=menu_2)        
menu_3=tkinter.Menu(menubar, tearoff=0)
menubar.add_cascade(label="Option", menu=menu_3) 

window.config(menu=menubar)

# 전화번호
call_number_label = tkinter.Label(window, text="전화번호")
call_number_label.configure(font=(80))  
call_number_label.place(x=40, y= 30)

call_number_text = tkinter.Text(window,width=32,height=3 )
call_number_text.configure(font=(40))
call_number_text.place(x=40, y =60)

# 현재시간
Current_time_label=tkinter.Label(window, text="현재 시간")
Current_time_label.configure(font=(40))  
Current_time_label.place(x=40, y=140)

Current_time_text=tkinter.Text(window,width=32,height=3 )
Current_time_text.configure(font=(40))
Current_time_text.place(x=40, y=170)

# 현재 위치
Current_loc_label=tkinter.Label(window, text="현재 위치")
Current_loc_label.configure(font=(40))  
Current_loc_label.place(x=40, y=250)

Current_loc_text=tkinter.Text(window,width=32,height=3 )
Current_loc_text.configure(font=(40))
Current_loc_text.place(x=40, y=280)


# 대화내용
Current_call_label=tkinter.Label(window, text="대화 내용")
Current_call_label.configure(font=(40))  
Current_call_label.place(x=450, y=30)

Current_call_text=tkinter.Text(window,width=100,height=8)
Current_call_text.place(x=450, y=60)
 
    

    
# 유사도 분석
similarity_label=tkinter.Label(window, text="유사도 분석")
similarity_label.configure(font=(40))  
similarity_label.place(x=450, y=250)

similarity_text=tkinter.Text(window,width=100,height=12 )
similarity_text.place(x=450, y=280)
    
    
    
# 분석 결과
result_label=tkinter.Label(window, text="분석 결과")
result_label.configure(font=(40))  
result_label.place(x=450, y=550)

result_text=tkinter.Text(window,width=100,height=20 )
result_text.place(x=450, y=580)
    
        
    
    
    
def read_voice(): # 음성 인식을 하는 함수
    r = Recognizer()
    mic = Microphone() # 마이크 객체
    with mic as source:
        audio = r.listen(source) # 음성 읽어오기
    voice_data = r.recognize_google(audio, language='ko')
    gpsphoto_label.insert(tkinter.CURRENT, voice_data)


# 녹음 버튼  callbutton.place(x=40, y=400)
record=tkinter.Button(window,width=12,height=2, text="일반 녹음" , command=read_voice)
record.configure(font=(40))
record.place(x=40, y=680) 

# Sound = tkinter.Button(window,width=12,height=2, text="NC 녹음")
# Sound.configure(font=(40))
# Sound.place(x=40, y=740)

# 분석 버튼
Analysis=tkinter.Button(window,width=12,height=2, text="분석" ,command=lambda: State(Current_call_text.get("1.0","end")) )
Analysis.configure(font=(40))
Analysis.place(x=40, y=740)




#전화벨 함수
def change_a():
    global photo2
    photo2 = tkinter.PhotoImage(file="./1.PNG")
    callbutton.config(image=photo2 ,command = change_b)    

    global photo4
    photo4 = tkinter.PhotoImage(file="./gps/압좌증후군.PNG")
    gpsphoto_label.config(image=photo4)
    
def change_b():
    Current_time_text.delete("1.0","end")
    call_number_text.delete("1.0","end")
    Current_loc_text.delete("1.0","end")
    global photo2
    photo2 = tkinter.PhotoImage(file="./2.PNG")
    callbutton.config(image=photo2 ,command = change_a)    
    now = datetime.now()   
    time=str(now.year)+"년 "+str(now.hour)+"시 "+str(now.minute)+"분 "+str(now.second)+"초"
    Current_time_text.insert(tkinter.CURRENT, time)
    call_number_text.insert(tkinter.CURRENT, "010-1234-5678")
    Current_loc_text.insert(tkinter.CURRENT, "경상북도 포항시 남구 청암로 77")



def change_c():
    global photo2
    photo2 = tkinter.PhotoImage(file="./3.PNG")
    callbutton.config(image=photo2 ,command = change_b) 
    
    
#전화벨 사진
photo = tkinter.PhotoImage(file="./1.PNG")
callbutton = tkinter.Button(window,width=230,height=230 ,image=photo ,command = change_b)
callbutton.place(x=40, y=400)


# gps 사진
gpsphoto = tkinter.PhotoImage(file="./gps/defalut.png")
gpsphoto_label = tkinter.Label(window,width=450,height=430 ,image=gpsphoto )
gpsphoto_label.place(x=1400, y=60)




    
# 거리 , 당진 , 의료기구 보유

tsd_label=tkinter.Label(window, text="지정 병원")
tsd_label.configure(font=(40))  
tsd_label.place(x=1400, y=550)

tsd_text=tkinter.Text(window,width=40,height=3 )
tsd_text.place(x=1400, y=580)


hospital_label=tkinter.Label(window, text="병원 사항")

hospital_label.configure(font=(40))  
hospital_label.place(x=1400, y=650)

hospital_text=tkinter.Text(window,width=40,height=10 )
hospital_text.place(x=1400, y=680)

    
window.mainloop()

# %%
# Out:
# hello
# hello
# hello

# %%
import tkinter

window=tkinter.Tk()
window.title("YUN DAE HEE")
window.geometry("640x400+100+100")
window.resizable(False, False)

count=0

def countUP():
    global count
    count +=1
    label.config(text=str(count))

label = tkinter.Label(window, text="0")
label.pack()

button = tkinter.Button(window, overrelief="solid", width=15, command=countUP, repeatdelay=1000, repeatinterval=100)
button.pack()

window.mainloop()
